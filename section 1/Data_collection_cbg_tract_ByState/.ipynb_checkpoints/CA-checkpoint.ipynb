key=3a0eaa719acf6cf3ba00e207a5d5b5d28f946c1b
#
# https://api.census.gov/data/2018/acs/acs5?get=B11011_003E,B11011_004E,B11011_005E,B11011_017E,B11011_018E,B21001_001E,B21001_002E,B21001_003E&for=tract:*&in=state:17&key=3a0eaa719acf6cf3ba00e207a5d5b5d28f946c1b
#
# https://api.census.gov/data/2018/acs/acs5/profile?get=DP04_0006E,DP04_0007E,DP04_0008E,DP04_0009E,DP04_0010E,DP04_0011E,DP04_0012E,DP04_0013E,DP04_0014E,DP04_0015E&for=tract:*&in=state:17&key=3a0eaa719acf6cf3ba00e207a5d5b5d28f946c1b
#
# As a result, you should have 5 json files: Tract_1.json, Tract_2.json, Tract_3.json, Tract_4.json, Tract_5.json, Trac_6.json

# %% [markdown]
# Now I am going to join the five json files. The data contains all zipcode in the U.S. But I need the data only for Illiois in this case, so I am going to join the data to the Illinois at the end.

# %%
#set column header
Tract_1 = pd.read_json('Tract_1.json')
new_header = Tract_1.iloc[0] 
Tract_1 = Tract_1[1:] 
Tract_1.columns = new_header
Tract_1
# Out:
# 0    B00001_001E B00002_001E B01002_001E B01002_002E B01002_003E B01001_001E  \
# 1            350         200        39.5        47.0        37.6        2649
# 2            400         200        42.2        42.5        41.7        2423
# 3            200         100        47.2        40.8        52.0        2180
# 4            450         200        33.3        34.9        32.2        2344
# 5            350         100        42.0        34.4        45.8        3759
# ...          ...         ...         ...         ...         ...         ...
# 3119         200          60        31.5        35.2        27.8        3943
# 3120         300          90        28.2        27.7        28.9        4387
# 3121         200          60        31.5        32.1        31.0        3625
# 3122         300         100        32.5        32.4        32.6        3509
# 3123         300         100        30.1        29.6        30.6        5011
#
# ...

# %%
#set column header
Tract_2 = pd.read_json('Tract_2.json')
new_header = Tract_2.iloc[0] 
Tract_2 = Tract_2[1:] 
Tract_2.columns = new_header
Tract_2
# Out:
# 0    B01001_046E B01001_047E B01001_048E B01001_049E B02001_001E B02001_002E  \
# 1             74          64          19          32        2649        2365
# 2             45          27          66          39        2423        2392
# 3             16          35          18         100        2180        2004
# 4             23          13           3           5        2344        1804
# 5            157          41          86         206        3759        1999
# ...          ...         ...         ...         ...         ...         ...
# 3119          69          35          33          37        3943        2867
# 3120          15          19           8           0        4387        2119
# 3121         105          66           0          13        3625        1810
# 3122          49          42           0          12        3509        1867
# 3123          70          38          11          12        5011        2892
#
# ...

# %%
#set column header
Tract_3 = pd.read_json('Tract_3.json')
new_header = Tract_3.iloc[0] 
Tract_3 = Tract_3[1:] 
Tract_3.columns = new_header
Tract_3
# Out:
# 0    B08134_008E B08134_009E B08134_010E B08201_001E B08201_002E B08201_003E  \
# 1            192          98          51        1038          72         344
# 2             30          56          66         944          32         251
# 3             16          43           5         966         201         277
# 4             38          56          88         866          39         346
# 5            144         152          52        1183         186         339
# ...          ...         ...         ...         ...         ...         ...
# 3119         102         115         474        1056         265         417
# 3120          61         332         367        1089         194         534
# 3121         101         284          62        1052          91         509
# 3122         139         213         238         866         157         376
# 3123         179         259         327        1348         279         598
#
# ...

# %%
#set column header
Tract_4 = pd.read_json('Tract_4.json')
new_header = Tract_4.iloc[0] 
Tract_4 = Tract_4[1:] 
Tract_4.columns = new_header
Tract_4
# Out:
# 0    B06009_003E B06009_004E B06009_005E B06009_006E B27011_001E B27011_002E  \
# 1            639         686         135          83        1421        1040
# 2            419         739         231         148        1375        1047
# 3            449         605         134          56        1262         859
# 4            583         511          98          70        1509        1157
# 5           1035         637         168          97        1787        1409
# ...          ...         ...         ...         ...         ...         ...
# 3119         715         530         147          47        2289        1706
# 3120         920         364         108          22        2664        1948
# 3121         752         234         149          49        1916        1410
# 3122         657         240         173          25        2142        1524
# 3123        1091         329         133          59        3090        2313
#
# ...

# %%
#Tract_5 column header
Tract_5 = pd.read_json('Tract_5.json')
new_header = Tract_5.iloc[0] 
Tract_5 = Tract_5[1:] 
Tract_5.columns = new_header
Tract_5
# Out:
# 0    B11011_003E B11011_004E B11011_005E B11011_017E B11011_018E B21001_001E  \
# 1            563         517          12         189          36        2035
# 2            569         517           9         205          18        1922
# 3            351         318          15         131         264        1781
# 4            355         327          28         236          98        1791
# 5            408         383          25         252         252        2912
# ...          ...         ...         ...         ...         ...         ...
# 3119         472         141         331          18         211        2660
# 3120         518         202         316          26         113        2980
# 3121         470         143         327          67         153        2427
# 3122         396          72         324          57         109        2500
# 3123         722         168         554          98         212        3610
#
# ...

# %%
#set column header
Tract_6 = pd.read_json('Tract_6.json')
new_header = Tract_6.iloc[0] 
Tract_6 = Tract_6[1:] 
Tract_6.columns = new_header
Tract_6
# Out:
# 0    DP04_0006E DP04_0007E DP04_0008E DP04_0009E DP04_0010E DP04_0011E  \
# 1          1206        958          0         38         15          3
# 2          1140        896         21         10         45          0
# 3          1212        795         11          6         91        109
# 4           950        717         32        115         52         32
# 5          1266        955         34         15          0          0
# ...         ...        ...        ...        ...        ...        ...
# 3119       1251        249          7        611        308         76
# 3120       1146        304         41        415        316         70
# 3121       1201        344          0        484        354         19
# 3122        989        144         40        406        327         30
# 3123       1510        366          0        637        382         91
#
# 0    DP04_0012E DP04_0013E DP04_0014E DP04_0015E state county   tract
# ...

# %%
#tmp
tmp = Tract_1.merge(Tract_2, how='inner', left_on=["state", "county", "tract"], right_on=["state", "county", "tract"])
tmp
# Out:
# 0    B00001_001E B00002_001E B01002_001E B01002_002E B01002_003E B01001_001E  \
# 0            350         200        39.5        47.0        37.6        2649
# 1            400         200        42.2        42.5        41.7        2423
# 2            200         100        47.2        40.8        52.0        2180
# 3            450         200        33.3        34.9        32.2        2344
# 4            350         100        42.0        34.4        45.8        3759
# ...          ...         ...         ...         ...         ...         ...
# 3118         200          60        31.5        35.2        27.8        3943
# 3119         300          90        28.2        27.7        28.9        4387
# 3120         200          60        31.5        32.1        31.0        3625
# 3121         300         100        32.5        32.4        32.6        3509
# 3122         300         100        30.1        29.6        30.6        5011
#
# ...

# %%
#join
tmp = tmp.merge(Tract_3, how='inner', left_on=["state", "county", "tract"], right_on=["state", "county", "tract"])
tmp
# Out:
# 0    B00001_001E B00002_001E B01002_001E B01002_002E B01002_003E B01001_001E  \
# 0            350         200        39.5        47.0        37.6        2649
# 1            400         200        42.2        42.5        41.7        2423
# 2            200         100        47.2        40.8        52.0        2180
# 3            450         200        33.3        34.9        32.2        2344
# 4            350         100        42.0        34.4        45.8        3759
# ...          ...         ...         ...         ...         ...         ...
# 3118         200          60        31.5        35.2        27.8        3943
# 3119         300          90        28.2        27.7        28.9        4387
# 3120         200          60        31.5        32.1        31.0        3625
# 3121         300         100        32.5        32.4        32.6        3509
# 3122         300         100        30.1        29.6        30.6        5011
#
# ...

# %%
tmp = tmp.merge(Tract_4, how='inner', left_on=["state", "county", "tract"], right_on=["state", "county", "tract"])
tmp
# Out:
# 0    B00001_001E B00002_001E B01002_001E B01002_002E B01002_003E B01001_001E  \
# 0            350         200        39.5        47.0        37.6        2649
# 1            400         200        42.2        42.5        41.7        2423
# 2            200         100        47.2        40.8        52.0        2180
# 3            450         200        33.3        34.9        32.2        2344
# 4            350         100        42.0        34.4        45.8        3759
# ...          ...         ...         ...         ...         ...         ...
# 3118         200          60        31.5        35.2        27.8        3943
# 3119         300          90        28.2        27.7        28.9        4387
# 3120         200          60        31.5        32.1        31.0        3625
# 3121         300         100        32.5        32.4        32.6        3509
# 3122         300         100        30.1        29.6        30.6        5011
#
# ...

# %%
tmp = tmp.merge(Tract_5, how='inner', left_on=["state", "county", "tract"], right_on=["state", "county", "tract"])
tmp
# Out:
# 0    B00001_001E B00002_001E B01002_001E B01002_002E B01002_003E B01001_001E  \
# 0            350         200        39.5        47.0        37.6        2649
# 1            400         200        42.2        42.5        41.7        2423
# 2            200         100        47.2        40.8        52.0        2180
# 3            450         200        33.3        34.9        32.2        2344
# 4            350         100        42.0        34.4        45.8        3759
# ...          ...         ...         ...         ...         ...         ...
# 3118         200          60        31.5        35.2        27.8        3943
# 3119         300          90        28.2        27.7        28.9        4387
# 3120         200          60        31.5        32.1        31.0        3625
# 3121         300         100        32.5        32.4        32.6        3509
# 3122         300         100        30.1        29.6        30.6        5011
#
# ...

# %%
tmp = tmp.merge(Tract_6, how='inner', left_on=["state", "county", "tract"], right_on=["state", "county", "tract"])
tmp
# Out:
# 0    B00001_001E B00002_001E B01002_001E B01002_002E B01002_003E B01001_001E  \
# 0            350         200        39.5        47.0        37.6        2649
# 1            400         200        42.2        42.5        41.7        2423
# 2            200         100        47.2        40.8        52.0        2180
# 3            450         200        33.3        34.9        32.2        2344
# 4            350         100        42.0        34.4        45.8        3759
# ...          ...         ...         ...         ...         ...         ...
# 3118         200          60        31.5        35.2        27.8        3943
# 3119         300          90        28.2        27.7        28.9        4387
# 3120         200          60        31.5        32.1        31.0        3625
# 3121         300         100        32.5        32.4        32.6        3509
# 3122         300         100        30.1        29.6        30.6        5011
#
# ...

# %%
tmp.to_csv('ACS_2018_5year__tract_IL.csv')
